# %%
import transformers


[i for i in dir(transformers) if "card" in i.lower()]
# Out:
# ['MODEL_CARD_NAME', 'ModelCard', 'modelcard']

# %%
dir(transformers.modelcard)
# Out:
# ['AUTOGENERATED_KERAS_COMMENT',
#  'AUTOGENERATED_TRAINER_COMMENT',
#  'Any',
#  'Dict',
#  'HFValidationError',
#  'List',
#  'METRIC_TAGS',
#  'MODEL_CARD_NAME',
#  'MODEL_FOR_AUDIO_CLASSIFICATION_MAPPING_NAMES',
#  'MODEL_FOR_CAUSAL_LM_MAPPING_NAMES',
#  'MODEL_FOR_CTC_MAPPING_NAMES',
#  'MODEL_FOR_IMAGE_CLASSIFICATION_MAPPING_NAMES',
#  'MODEL_FOR_IMAGE_SEGMENTATION_MAPPING_NAMES',
#  'MODEL_FOR_MASKED_LM_MAPPING_NAMES',
#  'MODEL_FOR_OBJECT_DETECTION_MAPPING_NAMES',
#  'MODEL_FOR_QUESTION_ANSWERING_MAPPING_NAMES',
#  'MODEL_FOR_SEQUENCE_CLASSIFICATION_MAPPING_NAMES',
#  'MODEL_FOR_SEQ_TO_SEQ_CAUSAL_LM_MAPPING_NAMES',
#  'MODEL_FOR_SPEECH_SEQ_2_SEQ_MAPPING_NAMES',
#  'MODEL_FOR_TABLE_QUESTION_ANSWERING_MAPPING_NAMES',
#  'MODEL_FOR_TOKEN_CLASSIFICATION_MAPPING_NAMES',
#  'MODEL_FOR_ZERO_SHOT_IMAGE_CLASSIFICATION_MAPPING_NAMES',
#  'ModelCard',
#  'Optional',
#  'ParallelMode',
#  'Path',
#  'TASK_MAPPING',
#  'TASK_TAG_TO_NAME_MAPPING',
#  'TrainingSummary',
#  'Union',
# ...

# %%
card = transformers.modelcard.model_info("bert-base-uncased")
card
# Out:
# ModelInfo: {
#   {'_id': '621ffdc036468d709f174338',
#    'author': None,
#    'cardData': {'datasets': ['bookcorpus', 'wikipedia'], 'language': 'en', 'license': 'apache-2.0', 'tags': ['exbert']},
#    'config': {'architectures': ['BertForMaskedLM'], 'model_type': 'bert'},
#    'disabled': False,
#    'downloads': 47341709,
#    'gated': False,
#    'id': 'bert-base-uncased',
#    'lastModified': '2022-11-16T15:15:39.000Z',
#    'library_name': 'transformers',
#    'likes': 717,
#    'mask_token': '[MASK]',
#    'model-index': None,
#    'modelId': 'bert-base-uncased',
#    'pipeline_tag': 'fill-mask',
#    'private': False,
#    'securityStatus': None,
#    'sha': '0a6aa9128b6194f4f3c4db429b6cb4891cdb421b',
#    'siblings': [RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': '.gitattributes', 'size': None},
#                 RepoFile: {'blob_id': None, 'lfs': None, 'rfilename': 'LICENSE', 'size': None},
# ...

# %%
import requests
from IPython.display import Markdown

model = "bert-base-cased"
readme_url = f"https://huggingface.co/{model}/raw/main/README.md"
readme = requests.get(readme_url).text

# Print the contents of the README file
Markdown(readme)
# Out:
# ---
# language: en
# tags:
# - exbert
# license: apache-2.0
# datasets:
# - bookcorpus
# - wikipedia
# ---
#
# # BERT base model (cased)
#
# Pretrained model on English language using a masked language modeling (MLM) objective. It was introduced in
# [this paper](https://arxiv.org/abs/1810.04805) and first released in
# [this repository](https://github.com/google-research/bert). This model is case-sensitive: it makes a difference between
# english and English.
#
# Disclaimer: The team releasing BERT did not write a model card for this model so this model card has been written by
# the Hugging Face team.
#
# ## Model description
#
# BERT is a transformers model pretrained on a large corpus of English data in a self-supervised fashion. This means it
# was pretrained on the raw texts only, with no humans labelling them in any way (which is why it can use lots of
# publicly available data) with an automatic process to generate inputs and labels from those texts. More precisely, it
# ...

# %%
import solara as sl
import requests
import reacton.ipyvuetify as v
from typing import Optional
from reacton.core import ValueElement


models = ["bert-base-cased", "bert-base-uncased", "google/bigbird-roberta-large", "stabilityai/stable-diffusion-2-1"]
datasets = ["wikipedia", "go_emotions", "glue"]
readme_url = "https://huggingface.co/{asset}/raw/main/README.md"


@sl.component
def FormatReadme(readme: str):
    """Format the metadata within a readme as scrollable
    
    The metadata in a card README is often long and ugly, and at the top of the file. 
    ex:
      ---
      text
      text
      text
      text
      text
      ---
      
      # Dataset Card
    We want to make that area scrollable so it doens't take up so much space
    """
    card_md = v.Container(
        style_=(
            "height: 700px; overflow-y: scroll;"
        )
    )
    # Strip out the newlines, just get the metadata and card content
    content = [i.strip() for i in readme.split("---", 2) if i]
    if len(content) == 2:
        meta, card = content
        # First add the card content
        card_md.add_children([sl.Markdown(card)])
        
        # Create a small, scrollable container for metadata
        meta_md = v.Container(
        style_=(
            "height: 150px; overflow-y: scroll;"
            )
        )
        # Add the metadata at the bottom
        card_md.add_children([sl.Markdown("### Metadata")])
        meta_md.add_children([sl.Markdown(meta)])
        card_md.add_children([meta_md])
    else:
        card = content[0]
        card_md.add_children([sl.Markdown(card)])


@sl.component
def ShowCard(asset: str):
    if not asset:
        sl.Markdown("# Choose Model or Dataset to view card")
        return
    is_dataset = asset in datasets
    if is_dataset:
        asset = f"datasets/{asset}"
    url = readme_url.format(asset=asset)
    readme = requests.get(url).text
    with sl.Card():
        FormatReadme(readme)


@sl.component
def Page():
    asset, set_asset = sl.use_state("")
    
    assets = models + datasets
    with sl.Columns([1, 3]):
        sl.Select("model/dataset", assets, asset, on_value=set_asset)
        ShowCard(asset)

Page()
# Out:
# Cannot show ipywidgets in text

# %%
text = """
Some text before the pattern
---
Line 1 of the pattern
Line 2 of the pattern
Line 3 of the pattern
---
Some text after the pattern
"""

# Define the regular expression to match the pattern
pattern = r"(?<=\n)(---\n(?:.*\n)*?---)(?=\n)"

# Search for the pattern in the text
match = re.search(pattern, text, flags=re.DOTALL)

# Print the start and end indices of the pattern
start_index = match.start()
end_index = match.end()
print(f"Start index: {start_index}")
print(f"End index: {end_index}")
# Out:
# Start index: 30
# End index: 103

# %%
import requests
import re
import solara as sl
import reacton.ipyvuetify as v

url = "https://huggingface.co/datasets/wikipedia/raw/main/README.md"
readme = requests.get(url).text
pattern = re.compile(r"(?<=\n)(---\n(?:.*\n)*?---)(?=\n)", flags=re.DOTALL)
# match = re.search(pattern, readme)#, flags=re.DOTALL)

@sl.component
def Page():
    card_md = v.Container(
    style_=(
        "height: 700px; overflow-y: scroll;"
        )
    )
    
#     start, end = match.start(), match.end()
#     meta, card = readme[start:end], readme[end:]
    meta, card = readme.split("---", 2)
    # Create a small, scrollable container for metadata
    meta_md = v.Container(
    style_=(
        "height: 100px; overflow-y: scroll;"
        )
    )
    meta_md.add_children([sl.Markdown(meta)])
    card_md.add_children([meta_md])
    
    meta_md  = v.Container(
    style_=(
        "height: 100px; overflow-y: scroll;"
        )
    )
    
    card_md.add_children([meta_md])
    card_md.add_children([sl.Markdown(readme)])

Page()
# Out:
# Component react.component(__main__.Page) raised exception ValueError('too many values to unpack (expected 2)')
# Traceback (most recent call last):
#   File "/Users/benepstein/Documents/GitHub/domino-dca-notebooks/.venv/lib/python3.9/site-packages/reacton/core.py", line 1627, in _render
#     root_element = el.component.f(*el.args, **el.kwargs)
#   File "/var/folders/2q/xy9rl8zn00b9_3ync0yk3jm40000gn/T/ipykernel_62715/2818771597.py", line 21, in Page
#     meta, card = readme.split("---", 2)
# ValueError: too many values to unpack (expected 2)
# Cannot show ipywidgets in text

# %%
readme
# Out:
# '---\nannotations_creators:\n- no-annotation\nlanguage_creators:\n- crowdsourced\npretty_name: Wikipedia\npaperswithcode_id: null\nlicense:\n- cc-by-sa-3.0\n- gfdl\ntask_categories:\n- text-generation\n- fill-mask\ntask_ids:\n- language-modeling\n- masked-language-modeling\nsource_datasets:\n- original\nmultilinguality:\n- multilingual\nsize_categories:\n- n<1K\n- 1K<n<10K\n- 10K<n<100K\n- 100K<n<1M\n- 1M<n<10M\nlanguage:\n- aa\n- ab\n- ace\n- af\n- ak\n- als\n- am\n- an\n- ang\n- ar\n- arc\n- arz\n- as\n- ast\n- atj\n- av\n- ay\n- az\n- azb\n- ba\n- bar\n- bcl\n- be\n- bg\n- bh\n- bi\n- bjn\n- bm\n- bn\n- bo\n- bpy\n- br\n- bs\n- bug\n- bxr\n- ca\n- cbk\n- cdo\n- ce\n- ceb\n- ch\n- cho\n- chr\n- chy\n- ckb\n- co\n- cr\n- crh\n- cs\n- csb\n- cu\n- cv\n- cy\n- da\n- de\n- din\n- diq\n- dsb\n- dty\n- dv\n- dz\n- ee\n- el\n- eml\n- en\n- eo\n- es\n- et\n- eu\n- ext\n- fa\n- ff\n- fi\n- fj\n- fo\n- fr\n- frp\n- frr\n- fur\n- fy\n- ga\n- gag\n- gan\n- gd\n- gl\n- glk\n- gn\n- gom\n- gor\n
# ...

# %%
stuff = [i.strip() for i in readme.split("---", 2) if i]

# %%
from IPython.display import Markdown
Markdown(stuff[1])
# Out:
# # Dataset Card for Wikipedia
#
# ## Table of Contents
# - [Dataset Description](#dataset-description)
#   - [Dataset Summary](#dataset-summary)
#   - [Supported Tasks and Leaderboards](#supported-tasks-and-leaderboards)
#   - [Languages](#languages)
# - [Dataset Structure](#dataset-structure)
#   - [Data Instances](#data-instances)
#   - [Data Fields](#data-fields)
#   - [Data Splits](#data-splits)
# - [Dataset Creation](#dataset-creation)
#   - [Curation Rationale](#curation-rationale)
#   - [Source Data](#source-data)
#   - [Annotations](#annotations)
#   - [Personal and Sensitive Information](#personal-and-sensitive-information)
# - [Considerations for Using the Data](#considerations-for-using-the-data)
#   - [Social Impact of Dataset](#social-impact-of-dataset)
#   - [Discussion of Biases](#discussion-of-biases)
#   - [Other Known Limitations](#other-known-limitations)
# - [Additional Information](#additional-information)
#   - [Dataset Curators](#dataset-curators)
# ...

# %%
def ascii_art_N():
    art = ""
    art += " _   _\n"
    art += "| \ | |\n"
    art += "|  \| |\n"
    art += "| |\  |\n"
    art += "|_| \_|\n"
    return art

print(ascii_art_N())


def ascii_art_E():
    art = ""
    art += " _____ \n"
    art += "| ____|\n"
    art += "|  _|  \n"
    art += "| |___ \n"
    art += "|_____|"
    return art

print(ascii_art_E())


def ascii_art_T():
    art = ""
    art += " _____ \n"
    art += "|_   _|\n"
    art += "  | |\n"
    art += "  | |\n"
    art += "  |_| \n"
    return art

print(ascii_art_T())




def ascii_art_NET():
    art = ""
    art += " _   _     _____     _____\n"
    art += "| \ | |   | ____|   |_   _|\n"
    art += "|  \| |   |  _|       | |  \n"
    art += "| |\  |   | |___      | |\n"
    art += "|_| \_|   |_____|     |_|\n"
    return art

print(ascii_art_NET())
# Out:
#  _   _
# | \ | |
# |  \| |
# | |\  |
# |_| \_|
#
#  _____
# | ____|
# |  _|
# | |___
# |_____|
#  _____
# |_   _|
#   | |
#   | |
#   |_|
#
#  _   _     _____     _____
# | \ | |   | ____|   |_   _|
# |  \| |   |  _|       | |
# | |\  |   | |___      | |
# |_| \_|   |_____|     |_|

# %%
from IPython.display import HTML
import requests


x = requests.get("https://huggingface.co/tasks/text-classification").text

HTML(x)
# Out:
# <!DOCTYPE html>
# <html class="">
# 	<head>
# 		<meta charset="utf-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=no" />
# 		<meta name="description" content="Learn about Text Classification using Machine Learning" />
# 		<meta property="fb:app_id" content="1321688464574422" />
# 		<meta name="twitter:card" content="summary_large_image" />
# 		<meta name="twitter:site" content="@huggingface" />
# 		<meta property="og:title" content="What is Text Classification? - Hugging Face" />
# 		<meta property="og:type" content="website" />
# 		<meta property="og:url" content="https://huggingface.co/tasks/text-classification" />
# 		<meta property="og:image" content="https://huggingface.co/front/thumbnails/v2-2.png" />
#
# 		<link rel="stylesheet" href="/front/build/style.773975d72.css" />
#
# 		<link rel="preconnect" href="https://fonts.gstatic.com" />
# 		<link
# ...

# %%
from datasets import load_dataset 
dataset = load_dataset("huggingface/cats-image")
# Out:
# ...
# No config specified, defaulting to: cats-image/image
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset cats-image downloaded and prepared to /Users/benepstein/.cache/huggingface/datasets/huggingface___cats-image/image/1.9.0/68fbc793fb10cd165e490867f5d61fa366086ea40c73e549a020103dcb4f597e. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset["test"]
# Out:
# Dataset({
#     features: ['image'],
#     num_rows: 1
# })
